# %% [markdown]
# <a href="https://colab.research.google.com/github/oshov/college-work/blob/main/MNSIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense, Flatten

(x_train, y_train),(x_test, y_test) = keras.datasets.mnist.load_data()

x_train.shape
x_train
x_test.shape
y_train

import matplotlib.pyplot as plt
plt.imshow(x_train[0])
x_train[0]
x_train = x_train/255
x_test = x_test/255
x_train[0]
model = Sequential()
model.add(Flatten(input_shape = (28, 28)))
model.add(Dense(128, activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))
model.summary()
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])
history = model.fit(x_train, y_train, epochs = 10, validation_split = 0.2)
model.predict(x_test)
y_prob = model.predict(x_test)
y_prob.argmax(axis = 1)
y_pred = y_prob.argmax(axis = 1)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_11 (Flatten)        (None, 784)               0
#
#  dense_19 (Dense)            (None, 128)               100480
#
#  dense_20 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2894 - accuracy: 0.9169 - val_loss: 0.1481 - val_accuracy: 0.9572
# Epoch 2/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1280 - accuracy: 0.9624 - val_loss: 0.1152 - val_accuracy: 0.9676
# Epoch 3/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0899 - accuracy: 0.9737 - val_loss: 0.1094 - val_accuracy: 0.9667
# Epoch 4/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0656 - accuracy: 0.9808 - val_loss: 0.0977 - val_accuracy: 0.9708
# Epoch 5/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0519 - accuracy: 0.9839 - val_loss: 0.0909 - val_accuracy: 0.9737
# Epoch 6/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0384 - accuracy: 0.9884 - val_loss: 0.0884 - val_accuracy: 0.9745
# Epoch 7/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0308 - accuracy: 0.9908 - val_loss: 0.0896 - val_accuracy: 0.9747
# Epoch 8/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0255 - accuracy: 0.9923 - val_loss: 0.0900 - val_accuracy: 0.9752
# Epoch 9/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0202 - accuracy: 0.9935 - val_loss: 0.0986 - val_accuracy: 0.9745
# Epoch 10/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.1064 - val_accuracy: 0.9719
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.975

# %%
plt.plot(history.history['loss'])

# %%
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])

# %%
plt.plot(history.history['val_accuracy'])

# %%
x_test[0]
plt.imshow(x_test[0])
model.predict(x_test[0].reshape(1,28,28)).argmax(axis = 1)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# array([7])
